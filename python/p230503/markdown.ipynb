# %% [markdown]
# # 제목1
# ## 제목2
# ### 제목3
# #### 제목4
# ##### 제목5
# ###### 제목6

# %% [markdown]
# # 순서 없는 리스트
# - 제목1
#     - 리스트1.1
#          - 리스트1.1.1
#     - 리스트1.2
#         - 리스트1.2.1
# - 리스트2
# - 리스트3

# %% [markdown]
# # 순서 있는 리스트
# 1. 리스트1
#     1. 리스트1.1
#           1. 리스트1.1.1
#     1. 리스트1.2
# 1. 리스트2
# 1. 리스트3

# %% [markdown]
# # 글자 진하게
# 진하게
# 하나
# 둘

# %% [markdown]
# # 수평선
# ---

# %% [markdown]
# # 코드
# ```python
# num = 5
# print(num)
# ```

# %% [markdown]
# # 인용구
# > 인용1
# > 인용2
# > 인용3

# %% [markdown]
# # 표
#
# 이름 | 전화번호 | 이메일
# - | - | -
# A | 010 | a@a.com
# B | 02 | b@b.com

# %% [markdown]
# # 이미지
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # url
# https://www.naver.com
