# %%
import requests
import json
import pandas as pd

# %%
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}
data_list = list()

for idx in range(1, 11):
    url = f'https://finance.naver.com/world/worldDayListJson.naver?symbol=SPI@SPX&fdtc=0&page={idx}'
    # 1. json파일 요청
    httpResponse = requests.get(url, headers=headers)
    
    # 2. json파일 -> str -> dict
#     dict_data = json.loads(httpResponse.text)
    # 2-1. json파일 -> dict
    dict_data = httpResponse.json()
    
    data_list.extend(dict_data)

# 3. dict -> DataFrame
# table = pd.json_normalize(data_list)
table = pd.DataFrame(data_list)

# # # 4. json파일로 저장
# # with open ('stock.json', 'w') as file:
# #     json.dump(data_list, file)

# # with open('stock.json', 'w') as file:
# #     file.write(json.dumps(data_list))

# %%
table
# Out:
#        symb      xymd     open     high      low     clos   diff  rate
# 0   SPI@SPX  20230426  4087.78  4089.67  4049.35  4055.99 -15.64 -0.38  \
# 1   SPI@SPX  20230425  4126.43  4126.43  4071.38  4071.63 -65.41 -1.58
# 2   SPI@SPX  20230424  4132.07  4142.41  4117.77  4137.04   3.52  0.09
# 3   SPI@SPX  20230421  4132.14  4138.02  4113.86  4133.52   3.73  0.09
# 4   SPI@SPX  20230420  4130.48  4148.57  4114.57  4129.79 -24.73 -0.60
# ..      ...       ...      ...      ...      ...      ...    ...   ...
# 95  SPI@SPX  20221207  3933.28  3957.57  3922.68  3933.92  -7.34 -0.19
# 96  SPI@SPX  20221206  3996.63  4001.51  3918.39  3941.26 -57.58 -1.44
# 97  SPI@SPX  20221205  4052.02  4052.45  3984.49  3998.84 -72.86 -1.79
# 98  SPI@SPX  20221202  4040.17  4080.48  4026.63  4071.70  -4.87 -0.12
# 99  SPI@SPX  20221201  4087.14  4100.51  4050.87  4076.57  -3.54 -0.09
#
#           gvol
# 0   2698867820
# 1   2559843600
# 2   2113777660
# 3   2304130060
# 4   2453132510
# ..         ...
# 95  2263753220
# 96  2367140660
# 97  2278161210
# 98  2076416490
# 99  2319414990
#
# [100 rows x 9 columns]

# %%
table.to_csv('naver_sise.csv', index=False)
print('** 저장 완료 **')
# Out:
# ** 저장 완료 **
