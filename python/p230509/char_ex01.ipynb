# %%
import matplotlib.pyplot as plt

# %%
data = [2, 5, 7, 4, 1]

plt.plot(data) # 입력된 데이터가 1개라면 y축의 기준으로 사용
# Out:
# list

# %%
# Out:
# ([<matplotlib.patches.Wedge at 0x18225773e50>,
# ...
#  [Text(1.0403989649906822, 0.3571694186885514, ''),
#   Text(0.09083724220568645, 1.0962429454406837, ''),
#   Text(-1.040398948270374, -0.3571694673931414, ''),
#   Text(0.6016430102375327, -0.9208831023709363, ''),
#   Text(1.0849974419956991, -0.18105399985305384, '')])
